# %% [markdown]
# <a href="https://colab.research.google.com/github/tesfayeaberalingane-beep/Tesfa-Website-/blob/main/Netflix_Users_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/Netflix Users Dataset.csv")

# %%
df.head()
# Out:
#    User_ID            Name  Age Country Subscription_Type  Watch_Time_Hours  \
# 0        1  James Martinez   18  France           Premium             80.26
# 1        2     John Miller   23     USA           Premium            321.75
# 2        3      Emma Davis   60      UK             Basic             35.89
# 3        4     Emma Miller   44     USA           Premium            261.56
# 4        5      Jane Smith   68     USA          Standard            909.30
#
#   Favorite_Genre  Last_Login
# 0          Drama  2024-05-12
# 1         Sci-Fi  2025-02-05
# 2         Comedy  2025-01-24
# 3    Documentary  2024-03-25
# 4          Drama  2025-01-14

# %%
df.describe()
# Out:
#             User_ID           Age  Watch_Time_Hours
# count  25000.000000  25000.000000      25000.000000
# mean   12500.500000     46.482880        500.468858
# std     7217.022701     19.594861        286.381815
# min        1.000000     13.000000          0.120000
# 25%     6250.750000     29.000000        256.567500
# 50%    12500.500000     46.000000        501.505000
# 75%    18750.250000     63.000000        745.732500
# max    25000.000000     80.000000        999.990000

# %%
df=df.drop(columns=['User_ID','Name'])

# %%
df.head()
# Out:
#    Age Country Subscription_Type  Watch_Time_Hours Favorite_Genre  Last_Login
# 0   18  France           Premium             80.26          Drama  2024-05-12
# 1   23     USA           Premium            321.75         Sci-Fi  2025-02-05
# 2   60      UK             Basic             35.89         Comedy  2025-01-24
# 3   44     USA           Premium            261.56    Documentary  2024-03-25
# 4   68     USA          Standard            909.30          Drama  2025-01-14

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ordinalEncoded=OrdinalEncoder(categories=[['Basic','Standard','Premium']])

# %%
df[['Subscription_Type']]=ordinalEncoded.fit_transform(df[['Subscription_Type']])

# %%
df.head()
# Out:
#    Age Country  Subscription_Type  Watch_Time_Hours Favorite_Genre  Last_Login
# 0   18  France                2.0             80.26          Drama  2024-05-12
# 1   23     USA                2.0            321.75         Sci-Fi  2025-02-05
# 2   60      UK                0.0             35.89         Comedy  2025-01-24
# 3   44     USA                2.0            261.56    Documentary  2024-03-25
# 4   68     USA                1.0            909.30          Drama  2025-01-14

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
df=pd.get_dummies(df,'Country','Favorite_Genre',drop_first=True)

# %%
df.head()
# Out:
#    Age  Subscription_Type  Watch_Time_Hours  CountryFavorite_GenreBrazil  \
# 0   18                2.0             80.26                        False
# 1   23                2.0            321.75                        False
# 2   60                0.0             35.89                        False
# 3   44                2.0            261.56                        False
# 4   68                1.0            909.30                        False
#
#    CountryFavorite_GenreCanada  CountryFavorite_GenreFrance  \
# 0                        False                         True
# 1                        False                        False
# 2                        False                        False
# 3                        False                        False
# 4                        False                        False
#
#    CountryFavorite_GenreGermany  CountryFavorite_GenreIndia  \
# 0                         False                       False
# ...

# %%
df['Last_login']=pd.to_datetime

# %%
df.head()
# Out:
#    Age  Subscription_Type  Watch_Time_Hours  CountryFavorite_GenreBrazil  \
# 0   18                2.0             80.26                        False
# 1   23                2.0            321.75                        False
# 2   60                0.0             35.89                        False
# 3   44                2.0            261.56                        False
# 4   68                1.0            909.30                        False
#
#    CountryFavorite_GenreCanada  CountryFavorite_GenreFrance  \
# 0                        False                         True
# 1                        False                        False
# 2                        False                        False
# 3                        False                        False
# 4                        False                        False
#
#    CountryFavorite_GenreGermany  CountryFavorite_GenreIndia  \
# 0                         False                       False
# ...

# %%
df['Days_last_login']=df['Last_login']

# %%
df['Last_login']=df

# %%
df.head()
# Out:
#    Age  Subscription_Type  Watch_Time_Hours  CountryFavorite_GenreBrazil  \
# 0   18                2.0             80.26                        False
# 1   23                2.0            321.75                        False
# 2   60                0.0             35.89                        False
# 3   44                2.0            261.56                        False
# 4   68                1.0            909.30                        False
#
#    CountryFavorite_GenreCanada  CountryFavorite_GenreFrance  \
# 0                        False                         True
# 1                        False                        False
# 2                        False                        False
# 3                        False                        False
# 4                        False                        False
#
#    CountryFavorite_GenreGermany  CountryFavorite_GenreIndia  \
# 0                         False                       False
# ...

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
scale =StandardScaler()

# %%
df[['Age', 'Watch_Time_Hours']] = scale.fit_transform(
    df[['Age', 'Watch_Time_Hours']]
)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
cols = ['Country_Brazil', 'Country_Canada']

for col in cols:
    df[col] = le.fit_transform(df[col])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country_Brazil'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1010690426.py in <cell line: 0>()
#       2
#       3 for col in cols:
# ...

# %%
from sklearn.cluster import KMeans
from matplotlib import pyplot as plt

# %%
W CSS =[]
